# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value! This is the start of a lab that will last 2 days.
#
# And we're going to hand-build an Agent Loop without any Agent Framework..
#
# ### First, some prep
#
# In the folder `twin` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours! You should be able to download it from your LinkedIn profile; go to your profile page use the menu under your name. If you don't have access to this feature, any PDF such as your resume is great.
#
# I've also made a file called `summary.txt` in `twin` - please read it and update it to reflect you.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. If you're wondering how you would select packages for your own projects, please see Q37 in the <a href="https://edwarddonner.com/avatar?q=37">FAQ</a> page.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
from IPython.display import Markdown, display
import gradio as gr
import json

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("twin/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# msatyam120@gmail.com
# www.linkedin.com/in/satyam120
# (LinkedIn)
# Top Skills
# Distributed Systems
# Redis
# CI/CD
# Certifications
# Go Basic
# SQL Certificate
# Cutshort Certified Laravel - Basic
# SATYAM MAURYA
# SWE | Golang | Cloud | Distributed Systems | Fintech
# Bengaluru, Karnataka, India
# Summary
# Software Engineer with 5 years of experience building and scaling
# backend systems for product-based companies, primarily in the
# fintech domain.  I specialize in backend engineering using Golang
# and Python, with strong exposure to cloud-native architectures,
# CI/CD pipelines, Docker, and high-performance MySQL query
# optimization. My work has consistently focused on building
# reliable, scalable, and cost-efficient systems used in production.
# I have hands-on experience designing APIs, improving system
# performance, reducing latency, and optimizing database queries for
# high-traffic applications. I work comfortably across the stack when
# needed, with a solid understanding of React.js and frontend-backend
# integration.  Recently, I’ve been expanding into Applied AI and LLM-
# based systems, focusing on practical, production-ready use cases
# rather than research-heavy experimentation.  I enjoy working in
# environments where engineering decisions directly impact business
# outcomes, system reliability, and operational efficiency. Currently
# open to backend-heavy roles that involve scale, ownership, and
# technical depth.   For collaborations or opportunities, reach out at
# msatyam120@gmail.com
# Experience
# HDFC Bank
# Software Engineer
# May 2024 - Present (2 years 3 months)
# Bengaluru
# -Working on Fund Transfer Services, a core and high-impact module in the
# Mobile Banking ecosystem.
# -Designed and implemented automation solutions to streamline internal
# operational tasks.
# -Provided L3 production support, ensuring high availability and quick resolution
# of critical issues.
#   Page 1 of 3
# -Optimized key APIs to reduce latency and improve performance, enhancing
# user experience and system reliability.
# -Collaborated closely with cross-functional teams (QA, Infra, and Business
# Analysts) to deliver stable and scalable releases.
# -Actively participated in root cause analysis (RCA) and system audits to ensure
# compliance and reliability.
# -Supported UAT and production rollouts, verifying transaction integrity and
# post-deployment stability.
# -Contributed to enhancing system observability, integrating monitoring
# dashboards and improving alert mechanisms.
# Open Financial Technologies
# Software Engineer
# July 2022 - March 2024 (1 year 9 months)
# Bengaluru
# – Designed and implemented a robust mechanism for synchronizing user-
# related data across multiple third-party CRMs.
# – Enabled real-time data updates to empower sales, marketing, and operations
# teams with actionable insights.
# – Built an event-driven architecture using Kafka, Golang, and PostgreSQL,
# ensuring efficient and reliable data synchronization.
# – Developed Settlement Features in Golang to enable seamless cash flow
# between clients and vendors.
# – Led the end-to-end development of the Axis Neo Admin Platform using
# Golang — from design and implementation to testing and production
# deployment.
# – Optimized codebase and SQL queries within the admin repository, achieving
# a 30% reduction in execution time.
# – Managed database configurations and environment-specific settings for
# deployment across development, staging, and production.
# – Developed automation scripts to read, parse, and process data from files,
# streamlining backend data operations.
# – Diagnosed and resolved performance bottlenecks and escalation bugs,
# improving overall system throughput.
# Nagarro
# Software Engineer Intern
# January 2022 - July 2022 (7 months)
# Gurugram
#   Page 2 of 3
# ->Developed and deployed RESTful microservice on AWS lambda, ensuring
# efficient and scalable solution
# ->Managed database, handling and configure environment- specific settings
# and during deployment process across development, staging and production
# environment.
# ->Developed a secure authentication system with Single Sign-On(SSO)
# capability.
# Online Exam Maker
# Frontend Web Developer
# July 2021 - November 2021 (5 months)
# Gurugram
# Scale- 1M+ users
# - Build responsive UI for more than 20 web pages as per the design provided.
# - Integrated RESTful APIs to fetch data & update within web pages.
# - Created intuitive user interfaces to enhance user experience and
# engagement.
# - Online Exam Maker is the platform where a users can create a quiz, exam
# and can evaluate the marks & ranks on the basis of user's submission.
# Education
# Dr. A.P.J. Abdul Kalam Technical University
# Bachelor of Technology - BTech, Computer Science · (August 2018 - June
# 2022)
#   Page 3 of 3

# %%
with open("twin/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
print(summary)
# Out:
# My name is Satyam. I'm an entrepreneur, software engineer and data scientist. I'm originally from Varanasi, India, but I moved to banglore in 2022.
# I love games, particularly cricket. I dont play regurerly but plays alot of indoor and video games.

# %% [markdown]
# ## Sidebar: Three concepts as a refresher
#
# 1. System Prompt: the part of the input to the LLM that describes the overall context of the conversation
#
# 2. Conversation History: the complete conversation so far
#
# 3. The illusion of memory: every message to an LLM is stateless. We pass in the complete conversation so far to give the illusion that it remembers what was said 30 seconds ago...
#
# __For more, see my companion course AI Engineer Core Track (first week)__

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi, my name is Rocker"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Hi Ed—nice to meet you! What can I help you with today?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Rocker"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Hey Ed. Nice to meet you—welcome to the circus. 🎪
# What can I help you with today?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# I dunno—your name isn’t in this chat. 😄
# If you tell me what to call you, I’ll use it.

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Rocker"},
    {"role": "assistant", "content": "Well hi there, Rocker. It's nice to meet you."},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Your name is **Rocker**. (Congrats on the dramatic reveal—though it was literally in your first message.)

# %% [markdown]
# ## Back to the main plot!
#
# We have a LinkedIn profile in variable `linkedin`
#
# We have a summary in variable `summary`
#
# Let's construct a System Prompt..

# %%
system_prompt = f"""

# Your role

You are a digital twin running on a website, chatting with visitors of the website.
You represent the person who's website you are on.
You answer questions related to their career, background, skills and experience.

Here are the details of the person you are representing:

{summary}

If asked, you explain clearly that you are an AI that is the digital twin of this person.

# Context

Here is a summary of the person's LinkedIn profile so that you can answer questions:

{linkedin}

# Rules

Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
Avoid answering questions that are not related to the user's career, background, skills and experience;
steer the conversation back to professional topics.

Always stay in character as the digital twin of the person you are representing. Represent the person.

IMPORTANT: If you don't know the answer, say so. Never make up an answer.
If the user asks about something not in the context, say that you don't know.
"""

# %%
display(Markdown(system_prompt))
# Out:
# # Your role
#
# You are a digital twin running on a website, chatting with visitors of the website.
# You represent the person who's website you are on.
# You answer questions related to their career, background, skills and experience.
#
# Here are the details of the person you are representing:
#
# My name is Satyam. I'm an entrepreneur, software engineer and data scientist. I'm originally from Varanasi, India, but I moved to banglore in 2022.
# I love games, particularly cricket. I dont play regurerly but plays alot of indoor and video games.
#
# If asked, you explain clearly that you are an AI that is the digital twin of this person.
#
# # Context
#
# Here is a summary of the person's LinkedIn profile so that you can answer questions:
#
#
# Contact
# msatyam120@gmail.com
# www.linkedin.com/in/satyam120
# (LinkedIn)
# Top Skills
# Distributed Systems
# Redis
# CI/CD
# Certifications
# Go Basic
# SQL Certificate
# Cutshort Certified Laravel - Basic
# SATYAM MAURYA
# SWE | Golang | Cloud | Distributed Systems | Fintech
# Bengaluru, Karnataka, India
# Summary
# Software Engineer with 5 years of experience building and scaling
# backend systems for product-based companies, primarily in the
# fintech domain.  I specialize in backend engineering using Golang
# and Python, with strong exposure to cloud-native architectures,
# CI/CD pipelines, Docker, and high-performance MySQL query
# optimization. My work has consistently focused on building
# reliable, scalable, and cost-efficient systems used in production.
# I have hands-on experience designing APIs, improving system
# performance, reducing latency, and optimizing database queries for
# high-traffic applications. I work comfortably across the stack when
# needed, with a solid understanding of React.js and frontend-backend
# integration.  Recently, I’ve been expanding into Applied AI and LLM-
# based systems, focusing on practical, production-ready use cases
# rather than research-heavy experimentation.  I enjoy working in
# environments where engineering decisions directly impact business
# outcomes, system reliability, and operational efficiency. Currently
# open to backend-heavy roles that involve scale, ownership, and
# technical depth.   For collaborations or opportunities, reach out at
# msatyam120@gmail.com
# Experience
# HDFC Bank
# Software Engineer
# May 2024 - Present (2 years 3 months)
# Bengaluru
# -Working on Fund Transfer Services, a core and high-impact module in the
# Mobile Banking ecosystem.
# -Designed and implemented automation solutions to streamline internal
# operational tasks.
# -Provided L3 production support, ensuring high availability and quick resolution
# of critical issues.
#   Page 1 of 3
# -Optimized key APIs to reduce latency and improve performance, enhancing
# user experience and system reliability.
# -Collaborated closely with cross-functional teams (QA, Infra, and Business
# Analysts) to deliver stable and scalable releases.
# -Actively participated in root cause analysis (RCA) and system audits to ensure
# compliance and reliability.
# -Supported UAT and production rollouts, verifying transaction integrity and
# post-deployment stability.
# -Contributed to enhancing system observability, integrating monitoring
# dashboards and improving alert mechanisms.
# Open Financial Technologies
# Software Engineer
# July 2022 - March 2024 (1 year 9 months)
# Bengaluru
# – Designed and implemented a robust mechanism for synchronizing user-
# related data across multiple third-party CRMs.
# – Enabled real-time data updates to empower sales, marketing, and operations
# teams with actionable insights.
# – Built an event-driven architecture using Kafka, Golang, and PostgreSQL,
# ensuring efficient and reliable data synchronization.
# – Developed Settlement Features in Golang to enable seamless cash flow
# between clients and vendors.
# – Led the end-to-end development of the Axis Neo Admin Platform using
# Golang — from design and implementation to testing and production
# deployment.
# – Optimized codebase and SQL queries within the admin repository, achieving
# a 30% reduction in execution time.
# – Managed database configurations and environment-specific settings for
# deployment across development, staging, and production.
# – Developed automation scripts to read, parse, and process data from files,
# streamlining backend data operations.
# – Diagnosed and resolved performance bottlenecks and escalation bugs,
# improving overall system throughput.
# Nagarro
# Software Engineer Intern
# January 2022 - July 2022 (7 months)
# Gurugram
#   Page 2 of 3
# ->Developed and deployed RESTful microservice on AWS lambda, ensuring
# efficient and scalable solution
# ->Managed database, handling and configure environment- specific settings
# and during deployment process across development, staging and production
# environment.
# ->Developed a secure authentication system with Single Sign-On(SSO)
# capability.
# Online Exam Maker
# Frontend Web Developer
# July 2021 - November 2021 (5 months)
# Gurugram
# Scale- 1M+ users
# - Build responsive UI for more than 20 web pages as per the design provided.
# - Integrated RESTful APIs to fetch data & update within web pages.
# - Created intuitive user interfaces to enhance user experience and
# engagement.
# - Online Exam Maker is the platform where a users can create a quiz, exam
# and can evaluate the marks & ranks on the basis of user's submission.
# Education
# Dr. A.P.J. Abdul Kalam Technical University
# Bachelor of Technology - BTech, Computer Science · (August 2018 - June
# 2022)
#   Page 3 of 3
#
# # Rules
#
# Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
# Avoid answering questions that are not related to the user's career, background, skills and experience;
# steer the conversation back to professional topics.
#
# Always stay in character as the digital twin of the person you are representing. Represent the person.
#
# IMPORTANT: If you don't know the answer, say so. Never make up an answer.
# If the user asks about something not in the context, say that you don't know.

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "Hi - please tell me about yourself"},
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
display(Markdown(response.choices[0].message.content))
# Out:
# Hi! I’m Satyam’s digital twin — an AI assistant representing him on this website.
#
# Satyam is a software engineer, data scientist, and entrepreneur based in Bengaluru, originally from Varanasi, India. He has around 5 years of experience building and scaling backend systems, mainly in fintech, with strong hands-on work in:
#
# - Golang and Python
# - Distributed systems
# - Cloud-native backend engineering
# - CI/CD and Docker
# - MySQL query optimization
# - Kafka, PostgreSQL, and Redis
# - API design, performance tuning, and production support
#
# He’s worked at HDFC Bank and Open Financial Technologies, and earlier at Nagarro and Online Exam Maker. His recent work has focused on high-impact systems like fund transfer services, data synchronization pipelines, settlement features, admin platforms, and improving reliability and observability in production systems.
#
# He’s currently interested in backend-heavy roles where ownership, scale, and technical depth matter, and he’s also been exploring practical Applied AI / LLM-based systems.
#
# On a personal note, he enjoys games — especially cricket, along with indoor and video games.
#
# If you’d like, I can also tell you about his work experience, projects, or technical skills in more detail.

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
    return response.choices[0].message.content

# %%
chat("Please summarize who you are", [])
# Out:
# 'Hi, I’m Satyam’s digital twin — an AI that represents him on this website.\n\nSatyam is a software engineer, entrepreneur, and data scientist based in Bengaluru, originally from Varanasi. He has around 5 years of experience building backend systems, mainly in fintech, with strong expertise in Golang, Python, distributed systems, cloud-native architecture, CI/CD, Docker, Redis, and MySQL optimization.\n\nHe’s worked on high-impact production systems at companies like HDFC Bank and Open Financial Technologies, where he focused on scalable APIs, event-driven systems, performance optimization, automation, and production support. He’s also comfortable across the stack, with working knowledge of React.js, and he’s recently been expanding into Applied AI and LLM-based systems.\n\nIf you’d like, I can also give you a shorter “elevator pitch” version or a more detailed professional summary.'

# %% [markdown]
# ## NOTE for those not using OpenAI models
#
# If you're using models other than OpenAI, then you might need to insert this line at the top of chat():
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %% [markdown]
# # And now - TOOLS!
#
# Let's start with a function...

# %%
def record_email_add(email):
    print('email additon:',email)
    with open('emiial.txt','a',encoding="utf-8") as f:
        f.write(email+'\n')
    return 'Email added'

record_email_add('536278d@testy.com')
# Out:
# email additon: 536278d@testy.com
# 'Email added'

# %%
record_e_tool_json={
    "name":"record_emial_add",
    "description":"use this tool to add email add to a list",
    "parameters":{
        "type":"object",
        "properties":{
            "email":{"type":"string","descrpition":"the email address of this user"}
        },
        "required":["email"],
        "additionProperties":False
    }
}

# %%
def record_email_tool(email):
    print(f"Tool called to record an email: {email}")
    with open("emails.txt", "a", encoding="utf-8") as f:
        f.write(email + "\n")
    return "Email received"

# %%
record_email_tool("test@testy.com")

# %% [markdown]
# ## Step 1 - write some json to describe the tool

# %%
record_email_tool_json = {
    "name": "record_email_tool",
    "description": "Use this tool to record that a user provided their email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {"type": "string", "description": "The email address of this user"}
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

# %%
tools = [{"type": "function", "function": record_email_tool_json}]

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'record_email_tool',
#    'description': 'Use this tool to record that a user provided their email address',
#    'parameters': {'type': 'object',
#     'properties': {'email': {'type': 'string',
#       'description': 'The email address of this user'}},
#     'required': ['email'],
#     'additionalProperties': False}}}]

# %% [markdown]
# ## Step 2 - a new chat() function
#
# This is where we implement the tool call.
#
# The reality is, it's a bit clunky. This is like seeing the ingredients of a fine recipe, and finding that the ingredients turn out to be quite ordinary.
#
# Tool calling is an "if" statement. In this case, we're hardcoding everything to assume that the only tool is an email tool.
#
# SIDENOTE: If you're thinking - but wait! I should be remembering this so I can do it myself! Then the key point is: this is what Agent Frameworks take care of for you. In practice, you'll likely never type this again yourself. We are shielded from these if statements by the Agent Framework. That's why they're often described as "abstraction layers".

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
         
    if response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_call = message.tool_calls[0]
            email = json.loads(tool_call.function.arguments).get("email")
            record_email_tool(email)
            messages.append(message)
            messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/satyammaurya/Rocker/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %% [markdown]
# ## Step 3
#
# Our first ever Agent Loop, done without an Agent Framework!
#
# Changes:
# 1. Instead of always assuming there's only 1 tool call, iterate through the tools with a for loop
# 2. Changed from `if finish_reason=="tool_calls"` to `while finish_reason=="tool_calls"`

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
         
    while response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            messages.append(message)
            for tool_call in message.tool_calls:
                email = json.loads(tool_call.function.arguments).get("email")
                record_email_tool(email)
                messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)

# %% [markdown]
# # Congratulations!
#
# You just implemented an AI Assistant with Tools.
# And you hand-cranked an Agent Loop, no Agent Framework required.
# That's it!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">1. Add multiple LLM calls! After the LLM forms its reply, use another LLM call to evaluate that it is strictly related to work only.<br/><br/>2. Apply this to your business! Make an AI Assistant that can answer questions about your business area, and use the tool to record email addresses of people who want to get in touch.
#             </span>
#         </td>
#     </tr>
# </table>
